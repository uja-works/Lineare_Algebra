# %%
2+3
# Out:
# 5

# %% [markdown]
# # Kapitel 1: Grundlagen
# ## Abschnitt 1: Grundlagen der Grundlagen
# ### Abschnitt 1: Grundlagen der Grundlagen der Grundlagen
# Hier geht's endlich los, und zwar mit einer Aufzählung:
# 1. Erster Punkt
# 2. Zweiter Punkt
# 4. ...
#
# Bulletpoints:
# - Ein Argument
# - ein anderes Argument
#
# Auch Formeln funktionieren: Im laufenden Text $E = mc^2$.
#
# Abgesetzt:
#
# $$ I = \int_a^b f(x)\, dx. $$

# %% [markdown]
# # Sympy (Symbolic python)

# %%
from sympy import *

# %% [markdown]
# Wir definieren `x` als Symbol für eine Variable.

# %%
x = symbols("x")

# %% [markdown]
# Damit können wir symbolisch rechnen:

# %%
1 + x*x + 2*x*x
# Out:
# 3*x**2 + 1

# %%
plot(sin(x), cos(x))

# %%
diff(x**2 + x,x)
# Out:
# 2*x + 1

# %%
integrate(x**2 + x,x)
# Out:
# x**3/3 + x**2/2
